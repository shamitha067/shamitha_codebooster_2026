# %% [markdown]
# <a href="https://colab.research.google.com/github/shamitha067/shamitha_codebooster_2026/blob/main/Day7/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chromadb sentence-transformers -q
print("Installation completed")
# Out:
# Installation completed

# %%
import pandas as pd
import numpy as np

from sentence_transformers import SentenceTransformer
import chromadb
print("All libraries impoerted successfully")
print(f"chromadb version: {chromadb.__version__}")
# Out:
# All libraries impoerted successfully
# chromadb version: 1.5.9

# %%
documents = {
    "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",
    "SQL is used to query databae",
    "Machine Learning trains model on data"
}

query_keyword = "vehicle"

print("-" * 60)
print(f"KEYWORD SEARCH FOR : '{query_keyword}")
print("-" * 60)

for i,doc in enumerate(documents):
  if query_keyword.lower()in doc.lower():
    print(f"FOUND[doc_(i)]:(doc)")
  else:
    print(f"MISSED[doc_(i)]:(doc)")

print()
# Out:
# ------------------------------------------------------------
# KEYWORD SEARCH FOR : 'vehicle
# ------------------------------------------------------------
# MISSED[doc_(i)]:(doc)
# MISSED[doc_(i)]:(doc)
# MISSED[doc_(i)]:(doc)
# FOUND[doc_(i)]:(doc)
# MISSED[doc_(i)]:(doc)

# %%
print("Loading embedding model... (may take 1 - 2 minutes on first run)")
model = SentenceTransformer('all-MiniLM-L6-V2')

print("Model Loaded successfully!!")
print(f"Model produces vectors of size: {model.get_sentence_embedding_dimension()}dimensions")
# Out:
# Loading embedding model... (may take 1 - 2 minutes on first run)
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-V2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# ...

# %%
sentence = "ETL is used to clean and transform data"

embedding = model.encode(sentence)

print(f"Input sentence: '{sentence}'")
print()
print(f"Embedding type: {type(embedding)}")
print(f"Embedding shape: {embedding.shape}")
print()
print(f"First 10 numbers: {embedding[:10].round(4)}")

print(f"Min value: {embedding.min():.4f}")
print(f"Max value: {embedding.max():.4f}")
# Out:
# Input sentence: 'ETL is used to clean and transform data'
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape: (384,)
#
# First 10 numbers: [-0.0784  0.0541  0.0224 -0.0389  0.0221 -0.0904  0.0007 -0.0152  0.0733
#   0.0362]
# Min value: -0.1381
# Max value: 0.1815

# %%
sentence = [
     "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",

]


embedding = model.encode(sentence)

print(f"Input sentence: '{sentence}'")
print()
print(f"Embedding type: {type(embedding)}")
print(f"Embedding shape: {embedding.shape}")
print()
print(f"First 10 numbers: {embedding[:10].round(4)}")

print(f"Min value: {embedding.min():.4f}")
print(f"Max value: {embedding.max():.4f}")
# Out:
# Input sentence: '['ETL is used to clean and transform data', 'A vehicle is mode of Transportation', 'Cars and Trucks are popular automobile']'
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape: (3, 384)
#
# First 10 numbers: [[-0.0784  0.0541  0.0224 ...  0.0011  0.0316  0.0009]
#  [ 0.0065 -0.0032 -0.0011 ...  0.0584  0.0424 -0.0333]
#  [ 0.0884 -0.0479  0.0264 ...  0.0145  0.0957  0.0275]]
# Min value: -0.2122
# Max value: 0.1815

# %%
documents = [
    "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",
    "SQL is used to query database",
    "Machine Learning trains model on data"
]

query_keyword = "vehicle"

print("=" * 30)
print(f"KEYWORD SEARCH FOR : '{query_keyword}'")
print("=" * 30)

for i, doc in enumerate(documents):
    if query_keyword.lower() in doc.lower():
        print(f"FOUND [Doc {i}] : {doc}")
    else:
        print(f"MISSED [Doc {i}] : {doc}")
# Out:
# ...
# KEYWORD SEARCH FOR : 'vehicle'
# ...
# MISSED [Doc 0] : ETL is used to clean and transform data
# FOUND [Doc 1] : A vehicle is mode of Transportation
# MISSED [Doc 2] : Cars and Trucks are popular automobile
# MISSED [Doc 3] : SQL is used to query database
# MISSED [Doc 4] : Machine Learning trains model on data

# %%
documents = [
    "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",
    "SQL is used to query database",
    "Machine Learning trains model on data"
]

keywords = ["vehicle", "cars", "trucks", "automobile"]

print("=" * 30)
print("SEARCH RESULTS")
print("=" * 30)

for i, doc in enumerate(documents):
    if any(keyword.lower() in doc.lower() for keyword in keywords):
        print(f"FOUND [Doc {i}] : {doc}")
    else:
        print(f"MISSED [Doc {i}] : {doc}")
# Out:
# ...
# SEARCH RESULTS
# ...
# MISSED [Doc 0] : ETL is used to clean and transform data
# FOUND [Doc 1] : A vehicle is mode of Transportation
# FOUND [Doc 2] : Cars and Trucks are popular automobile
# MISSED [Doc 3] : SQL is used to query database
# MISSED [Doc 4] : Machine Learning trains model on data

# %%
documents = [
    "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",
    "SQL is used to query database",
    "Machine Learning trains model on data"
]

query = "vehicle"

# Load model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Create embeddings
doc_embeddings = model.encode(documents)
query_embedding = model.encode(query)

print("-" * 60)
print(f"SEMANTIC SEARCH FOR : '{query}'")
print("-" * 60)

# Calculate similarities
scores = util.cos_sim(query_embedding, doc_embeddings)[0]

# Threshold can be adjusted
threshold = 0.25

for i, score in enumerate(scores):
    if score >= threshold:
        print(f"FOUND [Doc {i}] : {documents[i]}  (Score: {score:.4f})")
    else:
        print(f"MISSED [Doc {i}] : {documents[i]} (Score: {score:.4f})")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ------------------------------------------------------------
# SEMANTIC SEARCH FOR : 'vehicle'
# ------------------------------------------------------------
# MISSED [Doc 0] : ETL is used to clean and transform data (Score: 0.0857)
# FOUND [Doc 1] : A vehicle is mode of Transportation  (Score: 0.7242)
# FOUND [Doc 2] : Cars and Trucks are popular automobile  (Score: 0.5489)
# MISSED [Doc 3] : SQL is used to query database (Score: 0.1009)
# MISSED [Doc 4] : Machine Learning trains model on data (Score: 0.2150)

# %%
sentences = [
    "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",
]

embeddings = model.encode(sentences)

print(f"Number of sentence: {len(sentences)}")
print(f"Shape of embeddings array: {embeddings.shape}")
print()
print("Each row is one sentence's embedding :")
for i,sent in enumerate(sentences):
  print(f"Sentence {i}:shape={embeddings[i].shape},first 5 values ={embeddings[i][:5]}")
# Out:
# Number of sentence: 3
# Shape of embeddings array: (3, 384)
#
# Each row is one sentence's embedding :
# Sentence 0:shape=(384,),first 5 values =[-0.07843895  0.05409217  0.02240574 -0.03891188  0.02206611]
# Sentence 1:shape=(384,),first 5 values =[ 0.0065014  -0.00321199 -0.00112192  0.03151717 -0.00399763]
# Sentence 2:shape=(384,),first 5 values =[ 0.08842639 -0.04791024  0.02636236  0.02834844  0.0105739 ]

# %%
documents = {
    "Red is a bright color",
    "Deep learning is a part of Machine Leaning",
    "Machine Learning trains uses the first method preprocessing"
}

query_keyword = "vehicle"

print("-" * 60)
print(f"KEYWORD SEARCH FOR : '{query_keyword}")
print("-" * 60)

for i,doc in enumerate(documents):
  if query_keyword.lower()in doc.lower():
    print(f"FOUND[doc_(i)]:(doc)")
  else:
    print(f"MISSED[doc_(i)]:(doc)")

print()
# Out:
# ------------------------------------------------------------
# KEYWORD SEARCH FOR : 'vehicle
# ------------------------------------------------------------
# MISSED[doc_(i)]:(doc)
# MISSED[doc_(i)]:(doc)
# MISSED[doc_(i)]:(doc)
# FOUND[doc_(i)]:(doc)
# MISSED[doc_(i)]:(doc)

# %%
documents = [
    "Red is a bright color",
    "Deep learning is a part of Machine Leaning",
    "Machine Learning uses the first method preprocessing"
]

query = "ML model"

# Load model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Create embeddings
doc_embeddings = model.encode(documents)
query_embedding = model.encode(query)

print("-" * 60)
print(f"SEMANTIC SEARCH FOR : '{query}'")
print("-" * 60)

# Calculate similarities
scores = util.cos_sim(query_embedding, doc_embeddings)[0]

# Threshold can be adjusted
threshold = 0.25

for i, score in enumerate(scores):
    if score >= threshold:
        print(f"FOUND [Doc {i}] : {documents[i]}  (Score: {score:.4f})")
    else:
        print(f"MISSED [Doc {i}] : {documents[i]} (Score: {score:.4f})")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ------------------------------------------------------------
# SEMANTIC SEARCH FOR : 'ML model'
# ------------------------------------------------------------
# MISSED [Doc 0] : Red is a bright color (Score: 0.0870)
# FOUND [Doc 1] : Deep learning is a part of Machine Leaning  (Score: 0.3008)
# FOUND [Doc 2] : Machine Learning uses the first method preprocessing  (Score: 0.3287)

# %%
documents = [
    "Red is a bright color",
    "Rainbow is with 7 colors",
    "Speakers are connected to the device"
]

query = "colors"

# Load model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Create embeddings
doc_embeddings = model.encode(documents)
query_embedding = model.encode(query)

print("-" * 60)
print(f"SEMANTIC SEARCH FOR : '{query}'")
print("-" * 60)

# Calculate similarities
#scores = util.cos_sim(query_embedding, doc_embeddings)[0]

# Threshold can be adjusted
threshold = 0.25

for i, score in enumerate(scores):
    if score >= threshold:
        print(f"FOUND [Doc {i}] : {documents[i]}  (Score: {score:.4f})")
    else:
        print(f"MISSED [Doc {i}] : {documents[i]} (Score: {score:.4f})")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ------------------------------------------------------------
# SEMANTIC SEARCH FOR : 'colors'
# ------------------------------------------------------------
# FOUND [Doc 0] : Red is a bright color  (Score: 0.6069)
# FOUND [Doc 1] : Rainbow is with 7 colors  (Score: 0.5813)
# MISSED [Doc 2] : Speakers are connected to the device (Score: 0.1913)

# %%
chromadb_client = chromadb.Client()

collection = chromadb_client.get_or_create_collection("demo_notes")

print("chromadb client created (in memory mode)")
print(f"Collection name: demo_notes")
print(f"Documents in collection : {collection.count()}")
# Out:
# chromadb client created (in memory mode)
# Collection name: demo_notes
# Documents in collection : 0

# %%
sample_docs = [
    "ETL is used to clean and transform data",
    "A vehicle is mode of Transportation",
    "Cars and Trucks are popular automobile",
    "SQL is used to query database",
    "Machine Learning trains model on data"
]

sample_ids = ["doc001" , "doc002", "doc003", "doc004" , "doc005"]

sample_metadata = [
    {"subject" : "Data Engineering" ,"Topic":"ETL"},
    {"subject" : "Data Engineering" ,"Topic":"SQL"},
    {"subject" : "Machine Learning" ,"Topic":"ML model"},
    {"subject" : "Python" ,"Topic":"Pandas"},
    {"subject" : "Machine Learning" ,"Topic":"Neural Learning"}
]

collection.add(
    documents = sample_docs,
    ids = sample_ids,
    metadatas = sample_metadata
)
print(f"Documents added to collections")
print(f"Total documents now in collection: {collection.count()}")
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:00<00:00, 104MiB/s]
# Documents added to collections
# Total documents now in collection: 5

# %%
query = "how to clean and prepare data?"

results = collection.query(
    query_texts = [query],
    n_results = 3
)


print("RESULT KEYS AVAILABLE")
print(list(results.keys()))
# Out:
# RESULT KEYS AVAILABLE
# ['ids', 'embeddings', 'documents', 'uris', 'included', 'data', 'metadatas', 'distances']

# %%
print(f"Query: '{query}")
print("-" * 40)
print()

matched_docs = results['documents'][0]
matched_ids = results['ids'][0]
matched_distances = results['distances'][0]
matched_metadatas = results['metadatas'][0]

for rank, (doc,doc_id, dist, meta) in enumerate(zip(matched_docs, matched_ids, matched_distances, matched_metadatas)):
    print(f"Rank {rank} | ID: {doc_id} | Distance : {dist:.4f}")
    print(f" Subject: {meta['subject']}")
    print(f" Topic: {meta['Topic']}")
    print(f" Document: {doc}")
    print()
print("NOTICE: The results are about ETL and Pandas - exactly what 'clean and prepare data'")
print("Semantic search found them even though the words are different")
# Out:
# Query: 'how to clean and prepare data?
# ----------------------------------------
#
# Rank 0 | ID: doc001 | Distance : 1.1737
#  Subject: Data Engineering
#  Topic: ETL
#  Document: ETL is used to clean and transform data
#
# Rank 1 | ID: doc004 | Distance : 1.5378
#  Subject: Python
#  Topic: Pandas
#  Document: SQL is used to query database
#
# Rank 2 | ID: doc005 | Distance : 1.6907
#  Subject: Machine Learning
#  Topic: Neural Learning
#  Document: Machine Learning trains model on data
#
# NOTICE: The results are about ETL and Pandas - exactly what 'clean and prepare data'
# Semantic search found them even though the words are different
